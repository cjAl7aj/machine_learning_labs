# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

df = pd.read_csv("/content/covid19_statistics")

print("Shape:", df.shape)
print("\nColumn Names:")
print(df.columns.tolist())
print("\nData Types:")
print(df.dtypes)
print("\nFirst 5 rows:")
print(df.head())
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Shape: (237, 12)
#
# Column Names:
# ['Unnamed: 0', 'continent', 'country', 'cases.active', 'cases.critical', 'cases.recovered', 'cases.total', 'deaths.total', 'population(k)', 'test.total (k)', 'date', 'time_hms']
#
# Data Types:
# Unnamed: 0           int64
# continent           object
# country             object
# cases.active       float64
# cases.critical     float64
# cases.recovered    float64
# cases.total          int64
# deaths.total       float64
# population(k)      float64
# test.total (k)     float64
# date                object
# time_hms            object
# dtype: object
#
# First 5 rows:
#    Unnamed: 0      continent           country  cases.active  cases.critical  \
# 0           0           Asia             China      118977.0             NaN
# 1           1         Africa      Saint-Helena        2164.0             NaN
# ...
